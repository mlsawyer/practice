// %% [markdown]
// <a href="https://colab.research.google.com/github/mlsawyer/practice/blob/master/blank_swift_gpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %%
import tensorflow

// %%
import epoch

// %%
let a = 100

// %%
print(a)
// Out:
// 100
