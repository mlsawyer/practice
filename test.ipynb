# %% [markdown]
# <a href="https://colab.research.google.com/github/mlsawyer/practice/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test

# %%
a = 20

# %%
b = 40

# %%
c = a + b

# %%
print(c)
# Out:
# 60
